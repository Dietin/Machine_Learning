# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data=pd.read_csv('../Data/Dataset_Calorie.csv',index_col=0)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight  BMI_tags  Label
# 1                        1150.3008         8     13
# 2                        1585.0511         7      1
# 4                        1857.3982         7      4
# 6                        1794.9091         7      3
# 8                        1518.5351         7      0
# ...                            ...       ...    ...
# 23986                    1963.2002         9     26
# 23988                    2504.8106         9     30
# 23994                    2781.0725         9     31
# 23997                    2072.1753         9     27
# 23998                    2149.8144         9     27
#
# [10726 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  object
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
#  8   BMI_tags                     10726 non-null  int64
#  9   Label                        10726 non-null  int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 921.8+ KB

# %% [markdown]
# ### Unknown metadata
# - BMI_tags
# - Label

# %%
unknown=['BMI_tags','Label']
data=data.drop(unknown,axis=1)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %% [markdown]
# ### Transform gender into numerical

# %%
data['gender']=data['gender'].apply(lambda x: 0 if x=='F' else 1)
data
# Out:
#        age  weight(kg)  height(m)  gender        BMI       BMR
# 1        2   16.097862   0.932025       0  18.531612   958.584  \
# 2        4   14.619374   0.916687       0  17.397496   932.383
# 4        4   17.899918   0.997288       0  17.997414   977.578
# 6        3   13.532880   1.022786       0  12.936609   944.689
# 8        4   17.039484   1.053977       1  15.338909   799.229
# ...    ...         ...        ...     ...        ...       ...
# 23986   72   95.444236   1.631113       0  35.874169  1510.154
# 23988   85   97.976899   1.631409       0  36.812724  1473.418
# 23994   50   97.761259   1.631864       0  36.711217  1635.925
# 23997   57   96.829324   1.631290       0  36.386871  1593.981
# 23998   63   97.615186   1.633168       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  int64
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 754.2 KB

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight(kg)                   10726.0    61.647728   24.254566   12.005536
# height(m)                    10726.0     1.540276    0.186042    0.856328
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight(kg)                     45.538375    61.323460    83.484585
# height(m)                       1.564845     1.631282     1.632234
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight(kg)                     98.799820
# height(m)                       1.633223
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Transform height into cm, round the weight

# %%
data['height(m)']=data['height(m)'].apply(lambda x:x*100)
data['weight(kg)']=data['weight(kg)'].apply(lambda x: round(x))
data
# Out:
#        age  weight(kg)   height(m)  gender        BMI       BMR
# 1        2          16   93.202488       0  18.531612   958.584  \
# 2        4          15   91.668688       0  17.397496   932.383
# 4        4          18   99.728772       0  17.997414   977.578
# 6        3          14  102.278630       0  12.936609   944.689
# 8        4          17  105.397666       1  15.338909   799.229
# ...    ...         ...         ...     ...        ...       ...
# 23986   72          95  163.111254       0  35.874169  1510.154
# 23988   85          98  163.140906       0  36.812724  1473.418
# 23994   50          98  163.186416       0  36.711217  1635.925
# 23997   57          97  163.128970       0  36.386871  1593.981
# 23998   63          98  163.316817       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.rename(columns={'weight(kg)':'weight','height(m)':'height'},inplace=True)

# %%
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 1        2      16   93.202488       0  18.531612   958.584             1.2  \
# 2        4      15   91.668688       0  17.397496   932.383             1.7
# 4        4      18   99.728772       0  17.997414   977.578             1.9
# 6        3      14  102.278630       0  12.936609   944.689             1.9
# 8        4      17  105.397666       1  15.338909   799.229             1.9
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight                       10726.0    61.656349   24.254346   12.000000
# height                       10726.0   154.027584   18.604204   85.632771
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight                         46.000000    61.000000    83.000000
# height                        156.484525   163.128234   163.223354
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Filter the age
# - > 15

# %%
data=data[data['age']>15]
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 6000    16      52  159.620627       0  20.546999  1353.726             1.2  \
# 6002    16      49  161.203695       0  18.854317  1324.208             1.5
# 6010    16      52  159.233701       1  20.700007  1472.422             1.5
# 6014    16      49  160.025383       0  19.023991  1319.525             1.2
# 6016    16      48  160.189532       1  18.836919  1420.362             1.7
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 6000                     1624.4712
# 6002                     1986.3120
# 6010                     2208.6330
# 6014                     1583.4300
# 6016                     2414.6154
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [7418 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                               count         mean         std          min
# age                          7418.0    34.512537   16.683523    16.000000  \
# weight                       7418.0    74.607981   15.318408    48.000000
# height                       7418.0   163.006119    0.742508   158.761642
# gender                       7418.0     0.487193    0.499870     0.000000
# BMI                          7418.0    28.055802    5.686672    18.085729
# BMR                          7418.0  1573.504469  136.421130  1302.797000
# activity_level               7418.0     1.444217    0.223760     1.200000
# calories_to_maintain_weight  7418.0  2259.941566  313.938645  1563.356400
#
#                                      25%          50%          75%
# age                            22.000000    31.000000    42.000000  \
# weight                         61.000000    74.000000    90.000000
# height                        163.120555   163.185915   163.253802
# gender                          0.000000     0.000000     1.000000
# BMI                            22.716269    27.733425    33.642773
# BMR                          1472.150500  1557.963000  1634.942500
# activity_level                  1.300000     1.300000     1.700000
# calories_to_maintain_weight  2028.724050  2206.866300  2441.524500
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %%
X=data.drop(['calories_to_maintain_weight'],axis=1)
y=data['calories_to_maintain_weight']

# %%
normalizer = tf.keras.layers.experimental.preprocessing.Normalization(input_shape=(X.shape[1],),axis=-1)
normalizer.adapt(np.array(X))
print(normalizer.mean.numpy())
# Out:
# [3.4512539e+01 7.4607979e+01 1.6300612e+02 4.8719332e-01 2.8055801e+01
#  1.5735045e+03 1.4442167e+00]

# %% [markdown]
# ### Split the data

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8)
x_train.shape,x_test.shape
# Out:
# ((5934, 7), (1484, 7))

# %% [markdown]
# ### Create model

# %%
from tensorflow.keras import regularizers
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(128, input_shape=(X.shape[1],), activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(64, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(32, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(16, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(10,activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(1,activation='linear'),
])
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),)
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_6 (Normalizati (None, 7)                 15
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               1024
# _________________________________________________________________
# dense_36 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_38 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                170
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 12,084
# Trainable params: 12,069
# Non-trainable params: 15
# _________________________________________________________________

# %%
history=model.fit(x_train, y_train, epochs=200, batch_size=8,
                  validation_split=0.2)
# Out:
# Epoch 1/200
# 594/594 [==============================] - 1s 2ms/step - loss: 420.1897 - val_loss: 21.2344
# Epoch 2/200
# 594/594 [==============================] - 1s 1ms/step - loss: 32.4691 - val_loss: 25.4655
# Epoch 3/200
# 594/594 [==============================] - 1s 1ms/step - loss: 32.7612 - val_loss: 26.5810
# Epoch 4/200
# 594/594 [==============================] - 1s 1ms/step - loss: 33.1441 - val_loss: 36.7227
# Epoch 5/200
# 594/594 [==============================] - 1s 1ms/step - loss: 31.9031 - val_loss: 29.7689
# Epoch 6/200
# 594/594 [==============================] - 1s 1ms/step - loss: 30.4936 - val_loss: 29.0691
# Epoch 7/200
# 594/594 [==============================] - 1s 1ms/step - loss: 30.4402 - val_loss: 23.4066
# Epoch 8/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.9217 - val_loss: 40.7682
# Epoch 9/200
# 594/594 [==============================] - 1s 1ms/step - loss: 30.9186 - val_loss: 29.0482
# Epoch 10/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.0797 - val_loss: 39.7807
# Epoch 11/200
# 594/594 [==============================] - 1s 1ms/step - loss: 30.7706 - val_loss: 35.1740
# Epoch 12/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.8531 - val_loss: 24.1578
# Epoch 13/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.5556 - val_loss: 27.0460
# Epoch 14/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.7564 - val_loss: 23.6880
# Epoch 15/200
# 594/594 [==============================] - 1s 1ms/step - loss: 29.0026 - val_loss: 38.8871
# Epoch 16/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.5662 - val_loss: 30.0451
# Epoch 17/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.3502 - val_loss: 19.5485
# Epoch 18/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.6718 - val_loss: 25.2396
# Epoch 19/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.5946 - val_loss: 23.5268
# Epoch 20/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.1908 - val_loss: 20.7590
# Epoch 21/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.1804 - val_loss: 27.7019
# Epoch 22/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.8508 - val_loss: 33.7730
# Epoch 23/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.3762 - val_loss: 22.4497
# Epoch 24/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.3307 - val_loss: 23.3800
# Epoch 25/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.6199 - val_loss: 34.7509
# Epoch 26/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.5324 - val_loss: 36.4801
# Epoch 27/200
# 594/594 [==============================] - 1s 2ms/step - loss: 30.1401 - val_loss: 29.4571
# Epoch 28/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.6644 - val_loss: 33.6528
# Epoch 29/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.1964 - val_loss: 21.1059
# Epoch 30/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.6669 - val_loss: 23.0846
# Epoch 31/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.5887 - val_loss: 25.7445
# Epoch 32/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.2214 - val_loss: 29.1811
# Epoch 33/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.0369 - val_loss: 23.3505
# Epoch 34/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.5113 - val_loss: 23.0052
# Epoch 35/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.2239 - val_loss: 22.5013
# Epoch 36/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.9736 - val_loss: 27.8709
# Epoch 37/200
# 594/594 [==============================] - 1s 1ms/step - loss: 28.3108 - val_loss: 41.9369
# Epoch 38/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.9459 - val_loss: 21.5854
# Epoch 39/200
# 594/594 [==============================] - 1s 1ms/step - loss: 29.0179 - val_loss: 23.1421
# Epoch 40/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.2638 - val_loss: 29.2944
# Epoch 41/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.1371 - val_loss: 31.0929
# Epoch 42/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.9317 - val_loss: 34.3444
# Epoch 43/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.3772 - val_loss: 33.6547
# Epoch 44/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.9257 - val_loss: 22.2157
# Epoch 45/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.2427 - val_loss: 23.6662
# Epoch 46/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.5597 - val_loss: 23.4832
# Epoch 47/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.4408 - val_loss: 29.3115
# Epoch 48/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.6323 - val_loss: 20.9213
# Epoch 49/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.8322 - val_loss: 21.6738
# Epoch 50/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.1088 - val_loss: 25.2045
# Epoch 51/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.3134 - val_loss: 20.0103
# Epoch 52/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.9513 - val_loss: 19.2023
# Epoch 53/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.2878 - val_loss: 33.3529
# Epoch 54/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.4450 - val_loss: 20.2331
# Epoch 55/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.2298 - val_loss: 26.6370
# Epoch 56/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.2773 - val_loss: 20.6783
# Epoch 57/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7018 - val_loss: 26.2054
# Epoch 58/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7672 - val_loss: 24.4852
# Epoch 59/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.6433 - val_loss: 21.6629
# Epoch 60/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.3787 - val_loss: 50.0254
# Epoch 61/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7431 - val_loss: 30.0679
# Epoch 62/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.6968 - val_loss: 29.0436
# Epoch 63/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.2326 - val_loss: 25.5632
# Epoch 64/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.0914 - val_loss: 20.2249
# Epoch 65/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.0114 - val_loss: 47.4787
# Epoch 66/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.1414 - val_loss: 28.0769
# Epoch 67/200
# 594/594 [==============================] - 1s 1ms/step - loss: 27.2108 - val_loss: 23.0587
# Epoch 68/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.6268 - val_loss: 38.1717
# Epoch 69/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7712 - val_loss: 35.5336
# Epoch 70/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.2702 - val_loss: 27.7170
# Epoch 71/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.4474 - val_loss: 26.4678
# Epoch 72/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.8265 - val_loss: 29.1723
# Epoch 73/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.7833 - val_loss: 30.0871
# Epoch 74/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.1571 - val_loss: 20.9688
# Epoch 75/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.3008 - val_loss: 23.1997
# Epoch 76/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.0680 - val_loss: 20.5347
# Epoch 77/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.6804 - val_loss: 25.4802
# Epoch 78/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.6205 - val_loss: 31.6068
# Epoch 79/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.2617 - val_loss: 30.7028
# Epoch 80/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.3639 - val_loss: 27.1658
# Epoch 81/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.6415 - val_loss: 28.3902
# Epoch 82/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.6205 - val_loss: 34.9553
# Epoch 83/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.4338 - val_loss: 20.4718
# Epoch 84/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.1813 - val_loss: 22.2989
# Epoch 85/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7773 - val_loss: 25.8514
# Epoch 86/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.1040 - val_loss: 21.2172
# Epoch 87/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.5810 - val_loss: 21.0422
# Epoch 88/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8647 - val_loss: 42.2831
# Epoch 89/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.6862 - val_loss: 24.7378
# Epoch 90/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.1648 - val_loss: 37.4566
# Epoch 91/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7271 - val_loss: 21.8878
# Epoch 92/200
# 594/594 [==============================] - 1s 1ms/step - loss: 26.1014 - val_loss: 21.5179
# Epoch 93/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.1354 - val_loss: 22.5687
# Epoch 94/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.7885 - val_loss: 20.3164
# Epoch 95/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.4966 - val_loss: 19.6006
# Epoch 96/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.1777 - val_loss: 23.4904
# Epoch 97/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6897 - val_loss: 20.5809
# Epoch 98/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6095 - val_loss: 23.9763
# Epoch 99/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.9856 - val_loss: 26.8608
# Epoch 100/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.2594 - val_loss: 21.2215
# Epoch 101/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6633 - val_loss: 29.0158
# Epoch 102/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.9850 - val_loss: 19.3624
# Epoch 103/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.2780 - val_loss: 25.4701
# Epoch 104/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8220 - val_loss: 23.5131
# Epoch 105/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.6810 - val_loss: 18.5346
# Epoch 106/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7915 - val_loss: 23.2355
# Epoch 107/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.0639 - val_loss: 33.1465
# Epoch 108/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5895 - val_loss: 32.8793
# Epoch 109/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.8347 - val_loss: 26.2798
# Epoch 110/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7326 - val_loss: 22.2920
# Epoch 111/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.2648 - val_loss: 22.7941
# Epoch 112/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.3063 - val_loss: 19.8120
# Epoch 113/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.0507 - val_loss: 33.8358
# Epoch 114/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8730 - val_loss: 20.6604
# Epoch 115/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6277 - val_loss: 20.9116
# Epoch 116/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.1185 - val_loss: 28.1226
# Epoch 117/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.4626 - val_loss: 21.3735
# Epoch 118/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5979 - val_loss: 21.2974
# Epoch 119/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.4716 - val_loss: 23.2638
# Epoch 120/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7604 - val_loss: 24.5135
# Epoch 121/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6048 - val_loss: 29.8302
# Epoch 122/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.3785 - val_loss: 20.7077
# Epoch 123/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.3827 - val_loss: 22.2382
# Epoch 124/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.0169 - val_loss: 24.1440
# Epoch 125/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8843 - val_loss: 37.5822
# Epoch 126/200
# 594/594 [==============================] - 1s 1ms/step - loss: 25.1899 - val_loss: 19.9205
# Epoch 127/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5688 - val_loss: 31.3398
# Epoch 128/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.8722 - val_loss: 18.4059
# Epoch 129/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.6515 - val_loss: 24.1310
# Epoch 130/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.6102 - val_loss: 20.7242
# Epoch 131/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7983 - val_loss: 22.0542
# Epoch 132/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.7086 - val_loss: 19.5797
# Epoch 133/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7575 - val_loss: 21.5856
# Epoch 134/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.1887 - val_loss: 28.9169
# Epoch 135/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.3739 - val_loss: 28.0079
# Epoch 136/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.4024 - val_loss: 26.6761
# Epoch 137/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.1306 - val_loss: 19.8753
# Epoch 138/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.2886 - val_loss: 21.3713
# Epoch 139/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.9810 - val_loss: 22.9215
# Epoch 140/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.9497 - val_loss: 18.4831
# Epoch 141/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.9420 - val_loss: 18.6546
# Epoch 142/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6662 - val_loss: 23.4099
# Epoch 143/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8744 - val_loss: 20.4148
# Epoch 144/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.0637 - val_loss: 28.4172
# Epoch 145/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.5893 - val_loss: 32.0147
# Epoch 146/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5937 - val_loss: 19.2404
# Epoch 147/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.1923 - val_loss: 20.0103
# Epoch 148/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.0567 - val_loss: 20.5405
# Epoch 149/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6790 - val_loss: 19.3301
# Epoch 150/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.1878 - val_loss: 24.1792
# Epoch 151/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6717 - val_loss: 33.4243
# Epoch 152/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8635 - val_loss: 21.4925
# Epoch 153/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.4790 - val_loss: 20.5609
# Epoch 154/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7421 - val_loss: 20.8903
# Epoch 155/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6180 - val_loss: 23.9461
# Epoch 156/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7925 - val_loss: 20.8213
# Epoch 157/200
# 594/594 [==============================] - 1s 1ms/step - loss: 21.7158 - val_loss: 22.5388
# Epoch 158/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.6976 - val_loss: 19.7342
# Epoch 159/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.8844 - val_loss: 18.4555
# Epoch 160/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.2376 - val_loss: 18.7203
# Epoch 161/200
# 594/594 [==============================] - 1s 1ms/step - loss: 24.8336 - val_loss: 19.7747
# Epoch 162/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.6826 - val_loss: 22.4963
# Epoch 163/200
# 594/594 [==============================] - 1s 1ms/step - loss: 21.9260 - val_loss: 18.6874
# Epoch 164/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.9435 - val_loss: 18.8399
# Epoch 165/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.1362 - val_loss: 20.8536
# Epoch 166/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5759 - val_loss: 22.8592
# Epoch 167/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5448 - val_loss: 26.5061
# Epoch 168/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.9188 - val_loss: 25.6740
# Epoch 169/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.9291 - val_loss: 38.4377
# Epoch 170/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.1436 - val_loss: 24.4134
# Epoch 171/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7342 - val_loss: 22.3972
# Epoch 172/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5745 - val_loss: 24.3885
# Epoch 173/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7809 - val_loss: 33.5460
# Epoch 174/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5198 - val_loss: 19.2509
# Epoch 175/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.2880 - val_loss: 19.9704
# Epoch 176/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.6090 - val_loss: 20.8593
# Epoch 177/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.1734 - val_loss: 28.7906
# Epoch 178/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.8780 - val_loss: 20.8563
# Epoch 179/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5576 - val_loss: 19.9417
# Epoch 180/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.7820 - val_loss: 19.9345
# Epoch 181/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.1198 - val_loss: 23.9211
# Epoch 182/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5335 - val_loss: 18.7039
# Epoch 183/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.1836 - val_loss: 21.7234
# Epoch 184/200
# 594/594 [==============================] - 1s 1ms/step - loss: 21.9367 - val_loss: 19.8642
# Epoch 185/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.3285 - val_loss: 18.0882
# Epoch 186/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5852 - val_loss: 21.0582
# Epoch 187/200
# 594/594 [==============================] - 1s 1ms/step - loss: 21.8577 - val_loss: 26.6953
# Epoch 188/200
# 594/594 [==============================] - 1s 1ms/step - loss: 21.8015 - val_loss: 23.4414
# Epoch 189/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.9706 - val_loss: 23.0367
# Epoch 190/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.7969 - val_loss: 19.5923
# Epoch 191/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5671 - val_loss: 19.5301
# Epoch 192/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.3452 - val_loss: 20.9957
# Epoch 193/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.7388 - val_loss: 30.1919
# Epoch 194/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.7880 - val_loss: 19.0821
# Epoch 195/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5682 - val_loss: 20.1801
# Epoch 196/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.8761 - val_loss: 20.2942
# Epoch 197/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.2034 - val_loss: 18.4452
# Epoch 198/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.1458 - val_loss: 19.3715
# Epoch 199/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.2326 - val_loss: 18.4197
# Epoch 200/200
# 594/594 [==============================] - 1s 1ms/step - loss: 22.5281 - val_loss: 19.5780

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def plot_loss(history,start,end):
  x_index=[x for x in range (start,end)]
  plt.plot(x_index,history.history['loss'][start-1:end-1], label='loss')
  plt.plot(x_index,history.history['val_loss'][start-1:end-1], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss MAE')
  plt.title(f'Loss betweeh epoch {start} and {end}')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
plot_loss(history,5,200)

# %%
model.evaluate(x_test,y_test)
# Out:
# 47/47 [==============================] - 0s 638us/step - loss: 19.0739
# 19.07387924194336

# %%
predict=model.predict(x_test)
predict.squeeze()
# Out:
# array([2135.588 , 1798.3838, 2120.5527, ..., 2204.2986, 2120.45  ,
#        2189.98  ], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your true labels in a NumPy array called 'y_true'
# Assuming you have your predicted values in a NumPy array called 'y_pred'

# Calculate the difference between true labels and predicted values
diff = y_test - predict.squeeze()

# Plotting the difference
plt.plot(np.arange(len(diff)), diff)
plt.xlabel('Sample Index')
plt.ylabel('Difference')
plt.title('Regression: Difference between True Labels and Predicted Values')
plt.show()

# %%
diff.describe()
# Out:
# count    1484.000000
# mean       -6.704982
# std        22.826666
# min       -64.188342
# 25%       -16.458164
# 50%        -8.873504
# 75%         4.005484
# max        72.917899
# Name: calories_to_maintain_weight, dtype: float64

# %%
import numpy as np

test=np.array([21,48,155,0,20,1183,1.9],dtype=float) # single row data -> prediksi 1 data orang sesuai dengan atribut yg ada
test=np.expand_dims(test,axis=0)
test
# Out:
# array([[  21. ,   48. ,  155. ,    0. ,   20. , 1183. ,    1.9]])

# %%
model.predict(test)
# Out:
# array([[2440.0217]], dtype=float32)

# %%
model.save('model_2_linear.h5')
