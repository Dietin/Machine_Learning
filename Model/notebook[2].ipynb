# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data=pd.read_csv('../Data/Dataset_Calorie.csv',index_col=0)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight  BMI_tags  Label
# 1                        1150.3008         8     13
# 2                        1585.0511         7      1
# 4                        1857.3982         7      4
# 6                        1794.9091         7      3
# 8                        1518.5351         7      0
# ...                            ...       ...    ...
# 23986                    1963.2002         9     26
# 23988                    2504.8106         9     30
# 23994                    2781.0725         9     31
# 23997                    2072.1753         9     27
# 23998                    2149.8144         9     27
#
# [10726 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  object
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
#  8   BMI_tags                     10726 non-null  int64
#  9   Label                        10726 non-null  int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 921.8+ KB

# %% [markdown]
# ### Unknown metadata
# - BMI_tags
# - Label

# %%
unknown=['BMI_tags','Label']
data=data.drop(unknown,axis=1)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %% [markdown]
# ### Transform gender into numerical

# %%
data['gender']=data['gender'].apply(lambda x: 0 if x=='F' else 1)
data
# Out:
#        age  weight(kg)  height(m)  gender        BMI       BMR
# 1        2   16.097862   0.932025       0  18.531612   958.584  \
# 2        4   14.619374   0.916687       0  17.397496   932.383
# 4        4   17.899918   0.997288       0  17.997414   977.578
# 6        3   13.532880   1.022786       0  12.936609   944.689
# 8        4   17.039484   1.053977       1  15.338909   799.229
# ...    ...         ...        ...     ...        ...       ...
# 23986   72   95.444236   1.631113       0  35.874169  1510.154
# 23988   85   97.976899   1.631409       0  36.812724  1473.418
# 23994   50   97.761259   1.631864       0  36.711217  1635.925
# 23997   57   96.829324   1.631290       0  36.386871  1593.981
# 23998   63   97.615186   1.633168       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  int64
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 754.2 KB

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight(kg)                   10726.0    61.647728   24.254566   12.005536
# height(m)                    10726.0     1.540276    0.186042    0.856328
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight(kg)                     45.538375    61.323460    83.484585
# height(m)                       1.564845     1.631282     1.632234
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight(kg)                     98.799820
# height(m)                       1.633223
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Transform height into cm, round the weight

# %%
data['height(m)']=data['height(m)'].apply(lambda x:x*100)
data['weight(kg)']=data['weight(kg)'].apply(lambda x: round(x))
data
# Out:
#        age  weight(kg)   height(m)  gender        BMI       BMR
# 1        2          16   93.202488       0  18.531612   958.584  \
# 2        4          15   91.668688       0  17.397496   932.383
# 4        4          18   99.728772       0  17.997414   977.578
# 6        3          14  102.278630       0  12.936609   944.689
# 8        4          17  105.397666       1  15.338909   799.229
# ...    ...         ...         ...     ...        ...       ...
# 23986   72          95  163.111254       0  35.874169  1510.154
# 23988   85          98  163.140906       0  36.812724  1473.418
# 23994   50          98  163.186416       0  36.711217  1635.925
# 23997   57          97  163.128970       0  36.386871  1593.981
# 23998   63          98  163.316817       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.rename(columns={'weight(kg)':'weight','height(m)':'height'},inplace=True)

# %%
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 1        2      16   93.202488       0  18.531612   958.584             1.2  \
# 2        4      15   91.668688       0  17.397496   932.383             1.7
# 4        4      18   99.728772       0  17.997414   977.578             1.9
# 6        3      14  102.278630       0  12.936609   944.689             1.9
# 8        4      17  105.397666       1  15.338909   799.229             1.9
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight                       10726.0    61.656349   24.254346   12.000000
# height                       10726.0   154.027584   18.604204   85.632771
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight                         46.000000    61.000000    83.000000
# height                        156.484525   163.128234   163.223354
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Filter the age
# - > 15

# %%
data=data[data['age']>15]
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 6000    16      52  159.620627       0  20.546999  1353.726             1.2  \
# 6002    16      49  161.203695       0  18.854317  1324.208             1.5
# 6010    16      52  159.233701       1  20.700007  1472.422             1.5
# 6014    16      49  160.025383       0  19.023991  1319.525             1.2
# 6016    16      48  160.189532       1  18.836919  1420.362             1.7
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 6000                     1624.4712
# 6002                     1986.3120
# 6010                     2208.6330
# 6014                     1583.4300
# 6016                     2414.6154
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [7418 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                               count         mean         std          min
# age                          7418.0    34.512537   16.683523    16.000000  \
# weight                       7418.0    74.607981   15.318408    48.000000
# height                       7418.0   163.006119    0.742508   158.761642
# gender                       7418.0     0.487193    0.499870     0.000000
# BMI                          7418.0    28.055802    5.686672    18.085729
# BMR                          7418.0  1573.504469  136.421130  1302.797000
# activity_level               7418.0     1.444217    0.223760     1.200000
# calories_to_maintain_weight  7418.0  2259.941566  313.938645  1563.356400
#
#                                      25%          50%          75%
# age                            22.000000    31.000000    42.000000  \
# weight                         61.000000    74.000000    90.000000
# height                        163.120555   163.185915   163.253802
# gender                          0.000000     0.000000     1.000000
# BMI                            22.716269    27.733425    33.642773
# BMR                          1472.150500  1557.963000  1634.942500
# activity_level                  1.300000     1.300000     1.700000
# calories_to_maintain_weight  2028.724050  2206.866300  2441.524500
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %%
X=data.drop(['calories_to_maintain_weight'],axis=1)
y=data['calories_to_maintain_weight']

# %%
normalizer = tf.keras.layers.experimental.preprocessing.Normalization(input_shape=(X.shape[1],),axis=-1)
normalizer.adapt(np.array(X))
print(normalizer.mean.numpy())
# Out:
# [[3.4512547e+01 7.4608040e+01 1.6300609e+02 4.8719341e-01 2.8055813e+01
#   1.5735048e+03 1.4442170e+00]]

# %% [markdown]
# ### Split the data

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8)
x_train.shape,y_train.shape
# Out:
# ((5934, 7), (5934,))

# %% [markdown]
# ### Create model

# %%
from tensorflow.keras import regularizers
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(128, input_shape=(X.shape[1],), activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(64, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(32, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(16, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(10,activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(1,activation='linear'),
])
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 7)                15
#  n)
#
#  dense_7 (Dense)             (None, 128)               1024
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 16)                528
#
#  dense_11 (Dense)            (None, 8)                 136
#
#  dense_12 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 12,048
# Trainable params: 12,033
# Non-trainable params: 15
# _________________________________________________________________

# %%
history=model.fit(x_train, y_train, epochs=200, batch_size=8,
                  validation_split=0.2)
# Out:
# Epoch 1/200
# 594/594 [==============================] - 3s 3ms/step - loss: 411.9152 - val_loss: 28.5515
# Epoch 2/200
# 594/594 [==============================] - 3s 4ms/step - loss: 31.9343 - val_loss: 38.3397
# Epoch 3/200
# 594/594 [==============================] - 2s 3ms/step - loss: 31.6684 - val_loss: 58.4510
# Epoch 4/200
# 594/594 [==============================] - 3s 4ms/step - loss: 31.6767 - val_loss: 42.2379
# Epoch 5/200
# 594/594 [==============================] - 2s 4ms/step - loss: 32.7784 - val_loss: 33.2284
# Epoch 6/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.7004 - val_loss: 30.8410
# Epoch 7/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.7884 - val_loss: 46.4842
# Epoch 8/200
# 594/594 [==============================] - 1s 2ms/step - loss: 31.3434 - val_loss: 21.8359
# Epoch 9/200
# 594/594 [==============================] - 2s 3ms/step - loss: 31.0093 - val_loss: 26.1245
# Epoch 10/200
# 594/594 [==============================] - 1s 2ms/step - loss: 30.1838 - val_loss: 35.3962
# Epoch 11/200
# 594/594 [==============================] - 2s 3ms/step - loss: 32.3463 - val_loss: 42.4036
# Epoch 12/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.9894 - val_loss: 20.0804
# Epoch 13/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.4539 - val_loss: 28.7073
# Epoch 14/200
# 594/594 [==============================] - 1s 3ms/step - loss: 30.6215 - val_loss: 20.0499
# Epoch 15/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.5716 - val_loss: 32.5251
# Epoch 16/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.5271 - val_loss: 41.9160
# Epoch 17/200
# 594/594 [==============================] - 1s 2ms/step - loss: 30.1003 - val_loss: 30.8556
# Epoch 18/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.7351 - val_loss: 30.2513
# Epoch 19/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.7762 - val_loss: 25.2191
# Epoch 20/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.1192 - val_loss: 28.9831
# Epoch 21/200
# 594/594 [==============================] - 2s 4ms/step - loss: 28.3413 - val_loss: 24.0715
# Epoch 22/200
# 594/594 [==============================] - 2s 4ms/step - loss: 28.7565 - val_loss: 32.3114
# Epoch 23/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.1015 - val_loss: 39.2458
# Epoch 24/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.3921 - val_loss: 32.0236
# Epoch 25/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.6595 - val_loss: 28.1346
# Epoch 26/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.3820 - val_loss: 20.1130
# Epoch 27/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.8868 - val_loss: 43.8346
# Epoch 28/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.4352 - val_loss: 40.0916
# Epoch 29/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.3780 - val_loss: 24.3614
# Epoch 30/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.4645 - val_loss: 42.8868
# Epoch 31/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.5717 - val_loss: 31.4910
# Epoch 32/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.6288 - val_loss: 32.1227
# Epoch 33/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.7611 - val_loss: 22.5035
# Epoch 34/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.7783 - val_loss: 24.4212
# Epoch 35/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.5218 - val_loss: 40.3584
# Epoch 36/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.9884 - val_loss: 32.6686
# Epoch 37/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.5665 - val_loss: 22.4565
# Epoch 38/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.6367 - val_loss: 28.7170
# Epoch 39/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.3036 - val_loss: 22.3914
# Epoch 40/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.3390 - val_loss: 39.7376
# Epoch 41/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.6126 - val_loss: 22.5328
# Epoch 42/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.9970 - val_loss: 32.2654
# Epoch 43/200
# 594/594 [==============================] - 2s 4ms/step - loss: 27.2830 - val_loss: 39.3140
# Epoch 44/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.0632 - val_loss: 24.2594
# Epoch 45/200
# 594/594 [==============================] - 1s 2ms/step - loss: 29.3984 - val_loss: 21.9876
# Epoch 46/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.8155 - val_loss: 33.6167
# Epoch 47/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.8825 - val_loss: 23.6672
# Epoch 48/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.1499 - val_loss: 20.2584
# Epoch 49/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.9353 - val_loss: 21.0036
# Epoch 50/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.1079 - val_loss: 27.7747
# Epoch 51/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.1016 - val_loss: 34.9351
# Epoch 52/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.0371 - val_loss: 21.1699
# Epoch 53/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.6698 - val_loss: 24.5257
# Epoch 54/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.6560 - val_loss: 20.0755
# Epoch 55/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.2437 - val_loss: 21.4761
# Epoch 56/200
# 594/594 [==============================] - 1s 2ms/step - loss: 28.0238 - val_loss: 19.4367
# Epoch 57/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1111 - val_loss: 22.6632
# Epoch 58/200
# 594/594 [==============================] - 3s 5ms/step - loss: 24.7392 - val_loss: 25.2030
# Epoch 59/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.6949 - val_loss: 22.4541
# Epoch 60/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.8194 - val_loss: 20.1421
# Epoch 61/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.7519 - val_loss: 18.7720
# Epoch 62/200
# 594/594 [==============================] - 2s 4ms/step - loss: 26.1513 - val_loss: 21.5035
# Epoch 63/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.2041 - val_loss: 24.5472
# Epoch 64/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.8559 - val_loss: 21.3504
# Epoch 65/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.5572 - val_loss: 23.5677
# Epoch 66/200
# 594/594 [==============================] - 1s 2ms/step - loss: 27.1349 - val_loss: 23.8680
# Epoch 67/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.2017 - val_loss: 37.6921
# Epoch 68/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.5228 - val_loss: 19.2425
# Epoch 69/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.8985 - val_loss: 34.2768
# Epoch 70/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.9392 - val_loss: 25.0377
# Epoch 71/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.0697 - val_loss: 20.7482
# Epoch 72/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.9456 - val_loss: 18.9538
# Epoch 73/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.0129 - val_loss: 26.6478
# Epoch 74/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.3617 - val_loss: 22.6057
# Epoch 75/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.7837 - val_loss: 26.0968
# Epoch 76/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.4619 - val_loss: 22.3194
# Epoch 77/200
# 594/594 [==============================] - 1s 2ms/step - loss: 26.3791 - val_loss: 27.4253
# Epoch 78/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.6756 - val_loss: 33.5227
# Epoch 79/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.2677 - val_loss: 22.4536
# Epoch 80/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.9324 - val_loss: 21.1577
# Epoch 81/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.0701 - val_loss: 23.0745
# Epoch 82/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.4933 - val_loss: 22.3699
# Epoch 83/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.1378 - val_loss: 32.9915
# Epoch 84/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.6396 - val_loss: 22.5505
# Epoch 85/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.8668 - val_loss: 21.9748
# Epoch 86/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.4438 - val_loss: 23.7050
# Epoch 87/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8622 - val_loss: 41.5794
# Epoch 88/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.8131 - val_loss: 24.1663
# Epoch 89/200
# 594/594 [==============================] - 1s 3ms/step - loss: 23.6210 - val_loss: 33.5426
# Epoch 90/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.2805 - val_loss: 20.6525
# Epoch 91/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.3377 - val_loss: 26.4825
# Epoch 92/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.8618 - val_loss: 35.2335
# Epoch 93/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.7910 - val_loss: 23.4412
# Epoch 94/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.9700 - val_loss: 21.7880
# Epoch 95/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.1040 - val_loss: 25.9834
# Epoch 96/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.6301 - val_loss: 20.1460
# Epoch 97/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.3285 - val_loss: 22.2027
# Epoch 98/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.6148 - val_loss: 21.5059
# Epoch 99/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.3858 - val_loss: 20.9599
# Epoch 100/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.3570 - val_loss: 28.1474
# Epoch 101/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.3025 - val_loss: 30.5816
# Epoch 102/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.4979 - val_loss: 24.7095
# Epoch 103/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.6504 - val_loss: 26.5962
# Epoch 104/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.4233 - val_loss: 21.5179
# Epoch 105/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1473 - val_loss: 24.0275
# Epoch 106/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3787 - val_loss: 24.9646
# Epoch 107/200
# 594/594 [==============================] - 2s 4ms/step - loss: 23.7209 - val_loss: 19.8187
# Epoch 108/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.3526 - val_loss: 20.5997
# Epoch 109/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5981 - val_loss: 26.2620
# Epoch 110/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.2998 - val_loss: 24.2905
# Epoch 111/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.1568 - val_loss: 35.6165
# Epoch 112/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.7787 - val_loss: 18.9006
# Epoch 113/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.7430 - val_loss: 27.0200
# Epoch 114/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.6610 - val_loss: 20.3969
# Epoch 115/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.9759 - val_loss: 23.4675
# Epoch 116/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.9229 - val_loss: 28.3050
# Epoch 117/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.1505 - val_loss: 27.8025
# Epoch 118/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.7327 - val_loss: 29.5106
# Epoch 119/200
# 594/594 [==============================] - 1s 2ms/step - loss: 25.4780 - val_loss: 21.9457
# Epoch 120/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.9477 - val_loss: 40.8271
# Epoch 121/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8329 - val_loss: 18.3672
# Epoch 122/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8340 - val_loss: 20.5310
# Epoch 123/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.2451 - val_loss: 20.0943
# Epoch 124/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.3937 - val_loss: 29.8921
# Epoch 125/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.9759 - val_loss: 36.4654
# Epoch 126/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6219 - val_loss: 32.3667
# Epoch 127/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.0988 - val_loss: 20.4589
# Epoch 128/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.5407 - val_loss: 24.3462
# Epoch 129/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.6445 - val_loss: 22.4054
# Epoch 130/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.1425 - val_loss: 20.9940
# Epoch 131/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.4564 - val_loss: 24.8526
# Epoch 132/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.3562 - val_loss: 24.6510
# Epoch 133/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.4008 - val_loss: 21.7730
# Epoch 134/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.8728 - val_loss: 24.9712
# Epoch 135/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.5995 - val_loss: 18.5731
# Epoch 136/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.3630 - val_loss: 20.3116
# Epoch 137/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.0000 - val_loss: 20.1544
# Epoch 138/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.2338 - val_loss: 34.2632
# Epoch 139/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.8057 - val_loss: 24.6687
# Epoch 140/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.5605 - val_loss: 23.0309
# Epoch 141/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.9580 - val_loss: 23.6521
# Epoch 142/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8652 - val_loss: 20.9728
# Epoch 143/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.9484 - val_loss: 18.9860
# Epoch 144/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.9291 - val_loss: 20.1626
# Epoch 145/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.6204 - val_loss: 25.1715
# Epoch 146/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5261 - val_loss: 27.1197
# Epoch 147/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.5927 - val_loss: 23.1616
# Epoch 148/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.6341 - val_loss: 36.7002
# Epoch 149/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.9490 - val_loss: 19.9323
# Epoch 150/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.7382 - val_loss: 18.6530
# Epoch 151/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.5268 - val_loss: 25.4301
# Epoch 152/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.4115 - val_loss: 21.2136
# Epoch 153/200
# 594/594 [==============================] - 1s 1ms/step - loss: 23.8019 - val_loss: 19.3145
# Epoch 154/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.9297 - val_loss: 20.8512
# Epoch 155/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.4718 - val_loss: 20.0742
# Epoch 156/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.3977 - val_loss: 18.9085
# Epoch 157/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.2067 - val_loss: 20.0130
# Epoch 158/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.2639 - val_loss: 36.0844
# Epoch 159/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.0617 - val_loss: 22.5202
# Epoch 160/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.8458 - val_loss: 17.4372
# Epoch 161/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.0603 - val_loss: 18.3919
# Epoch 162/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.5607 - val_loss: 22.9055
# Epoch 163/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8971 - val_loss: 24.1491
# Epoch 164/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.9152 - val_loss: 27.4699
# Epoch 165/200
# 594/594 [==============================] - 1s 3ms/step - loss: 22.5480 - val_loss: 27.6736
# Epoch 166/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1009 - val_loss: 20.7837
# Epoch 167/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.9947 - val_loss: 20.4699
# Epoch 168/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.9416 - val_loss: 33.5028
# Epoch 169/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.5238 - val_loss: 21.0204
# Epoch 170/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5571 - val_loss: 22.1836
# Epoch 171/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.9128 - val_loss: 18.2923
# Epoch 172/200
# 594/594 [==============================] - 1s 2ms/step - loss: 24.7458 - val_loss: 22.2314
# Epoch 173/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.3315 - val_loss: 29.1416
# Epoch 174/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.4739 - val_loss: 22.1999
# Epoch 175/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.4132 - val_loss: 19.6376
# Epoch 176/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.1250 - val_loss: 19.2963
# Epoch 177/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.9135 - val_loss: 18.0712
# Epoch 178/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8498 - val_loss: 23.6594
# Epoch 179/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.7210 - val_loss: 18.2312
# Epoch 180/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.1775 - val_loss: 18.9326
# Epoch 181/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.4780 - val_loss: 30.7075
# Epoch 182/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.1703 - val_loss: 19.6246
# Epoch 183/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.7905 - val_loss: 29.3512
# Epoch 184/200
# 594/594 [==============================] - 2s 4ms/step - loss: 22.3993 - val_loss: 26.9863
# Epoch 185/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.7705 - val_loss: 22.2863
# Epoch 186/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.7961 - val_loss: 20.0753
# Epoch 187/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.4635 - val_loss: 17.6674
# Epoch 188/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.0658 - val_loss: 42.6798
# Epoch 189/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.2207 - val_loss: 20.6671
# Epoch 190/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.7963 - val_loss: 21.2461
# Epoch 191/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.1605 - val_loss: 24.9935
# Epoch 192/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.8019 - val_loss: 18.9017
# Epoch 193/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.8319 - val_loss: 20.7074
# Epoch 194/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.5612 - val_loss: 18.8082
# Epoch 195/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.3806 - val_loss: 19.3976
# Epoch 196/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.9424 - val_loss: 27.5663
# Epoch 197/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.3301 - val_loss: 26.9892
# Epoch 198/200
# 594/594 [==============================] - 1s 2ms/step - loss: 21.6912 - val_loss: 18.8942
# Epoch 199/200
# 594/594 [==============================] - 1s 2ms/step - loss: 22.2154 - val_loss: 24.5023
# Epoch 200/200
# 594/594 [==============================] - 1s 2ms/step - loss: 23.4186 - val_loss: 22.2912

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def plot_loss(history,start,end):
  x_index=[x for x in range (start,end)]
  plt.plot(x_index,history.history['loss'][start-1:end-1], label='loss')
  plt.plot(x_index,history.history['val_loss'][start-1:end-1], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss MAE')
  plt.title(f'Loss betweeh epoch {start} and {end}')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
plot_loss(history,5,200)

# %%
model.evaluate(x_test,y_test)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 22.2371
# 22.23706817626953

# %%
predict=model.predict(x_test)
predict.squeeze()
# Out:
# 47/47 [==============================] - 0s 1ms/step
# array([2357.5786, 2049.5562, 2373.3489, ..., 2369.638 , 2113.6455,
#        2122.6072], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your true labels in a NumPy array called 'y_true'
# Assuming you have your predicted values in a NumPy array called 'y_pred'

# Calculate the difference between true labels and predicted values
diff = y_test - predict.squeeze()

# Plotting the difference
plt.plot(np.arange(len(diff)), diff)
plt.xlabel('Sample Index')
plt.ylabel('Difference')
plt.title('Regression: Difference between True Labels and Predicted Values')
plt.show()

# %%
diff.describe()
# Out:
# count    1484.000000
# mean       -0.850108
# std        29.740036
# min       -98.127627
# 25%       -15.980158
# 50%        -7.149408
# 75%        11.087684
# max       120.507975
# Name: calories_to_maintain_weight, dtype: float64

# %%
import numpy as np

test=np.array([21,48,155,0,20,1183,1.9],dtype=float) # single row data -> prediksi 1 data orang sesuai dengan atribut yg ada
test=np.expand_dims(test,axis=0)
test
# Out:
# array([[  21. ,   48. ,  155. ,    0. ,   20. , 1183. ,    1.9]])

# %%
model.predict(test)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# array([[2460.3591]], dtype=float32)

# %%
# model.save('model_2_linear.h5')
