# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data=pd.read_csv('../Data/Dataset_Calorie.csv',index_col=0)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight  BMI_tags  Label
# 1                        1150.3008         8     13
# 2                        1585.0511         7      1
# 4                        1857.3982         7      4
# 6                        1794.9091         7      3
# 8                        1518.5351         7      0
# ...                            ...       ...    ...
# 23986                    1963.2002         9     26
# 23988                    2504.8106         9     30
# 23994                    2781.0725         9     31
# 23997                    2072.1753         9     27
# 23998                    2149.8144         9     27
#
# [10726 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  object
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
#  8   BMI_tags                     10726 non-null  int64
#  9   Label                        10726 non-null  int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 921.8+ KB

# %% [markdown]
# ### Unknown metadata
# - BMI_tags
# - Label

# %%
unknown=['BMI_tags','Label']
data=data.drop(unknown,axis=1)
data
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level
# 1        2   16.097862   0.932025      F  18.531612   958.584             1.2  \
# 2        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 4        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 6        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 8        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 23986   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 23988   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 23994   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 23997   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 23998   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %% [markdown]
# ### Transform gender into numerical

# %%
data['gender']=data['gender'].apply(lambda x: 0 if x=='F' else 1)
data
# Out:
#        age  weight(kg)  height(m)  gender        BMI       BMR
# 1        2   16.097862   0.932025       0  18.531612   958.584  \
# 2        4   14.619374   0.916687       0  17.397496   932.383
# 4        4   17.899918   0.997288       0  17.997414   977.578
# 6        3   13.532880   1.022786       0  12.936609   944.689
# 8        4   17.039484   1.053977       1  15.338909   799.229
# ...    ...         ...        ...     ...        ...       ...
# 23986   72   95.444236   1.631113       0  35.874169  1510.154
# 23988   85   97.976899   1.631409       0  36.812724  1473.418
# 23994   50   97.761259   1.631864       0  36.711217  1635.925
# 23997   57   96.829324   1.631290       0  36.386871  1593.981
# 23998   63   97.615186   1.633168       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10726 entries, 1 to 23998
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          10726 non-null  int64
#  1   weight(kg)                   10726 non-null  float64
#  2   height(m)                    10726 non-null  float64
#  3   gender                       10726 non-null  int64
#  4   BMI                          10726 non-null  float64
#  5   BMR                          10726 non-null  float64
#  6   activity_level               10726 non-null  float64
#  7   calories_to_maintain_weight  10726 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 754.2 KB

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight(kg)                   10726.0    61.647728   24.254566   12.005536
# height(m)                    10726.0     1.540276    0.186042    0.856328
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight(kg)                     45.538375    61.323460    83.484585
# height(m)                       1.564845     1.631282     1.632234
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight(kg)                     98.799820
# height(m)                       1.633223
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Transform height into cm, round the weight

# %%
data['height(m)']=data['height(m)'].apply(lambda x:x*100)
data['weight(kg)']=data['weight(kg)'].apply(lambda x: round(x))
data
# Out:
#        age  weight(kg)   height(m)  gender        BMI       BMR
# 1        2          16   93.202488       0  18.531612   958.584  \
# 2        4          15   91.668688       0  17.397496   932.383
# 4        4          18   99.728772       0  17.997414   977.578
# 6        3          14  102.278630       0  12.936609   944.689
# 8        4          17  105.397666       1  15.338909   799.229
# ...    ...         ...         ...     ...        ...       ...
# 23986   72          95  163.111254       0  35.874169  1510.154
# 23988   85          98  163.140906       0  36.812724  1473.418
# 23994   50          98  163.186416       0  36.711217  1635.925
# 23997   57          97  163.128970       0  36.386871  1593.981
# 23998   63          98  163.316817       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 1                 1.2                    1150.3008
# 2                 1.7                    1585.0511
# 4                 1.9                    1857.3982
# 6                 1.9                    1794.9091
# 8                 1.9                    1518.5351
# ...               ...                          ...
# 23986             1.3                    1963.2002
# 23988             1.7                    2504.8106
# 23994             1.7                    2781.0725
# 23997             1.3                    2072.1753
# 23998             1.2                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.rename(columns={'weight(kg)':'weight','height(m)':'height'},inplace=True)

# %%
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 1        2      16   93.202488       0  18.531612   958.584             1.2  \
# 2        4      15   91.668688       0  17.397496   932.383             1.7
# 4        4      18   99.728772       0  17.997414   977.578             1.9
# 6        3      14  102.278630       0  12.936609   944.689             1.9
# 8        4      17  105.397666       1  15.338909   799.229             1.9
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 1                        1150.3008
# 2                        1585.0511
# 4                        1857.3982
# 6                        1794.9091
# 8                        1518.5351
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [10726 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                                count         mean         std         min
# age                          10726.0    26.778575   18.201675    2.000000  \
# weight                       10726.0    61.656349   24.254346   12.000000
# height                       10726.0   154.027584   18.604204   85.632771
# gender                       10726.0     0.480515    0.499643    0.000000
# BMI                          10726.0    24.788317    6.954637   10.342285
# BMR                          10726.0  1442.049923  250.686166  667.941000
# activity_level               10726.0     1.487451    0.239625    1.200000
# calories_to_maintain_weight  10726.0  2118.574075  388.425427  953.540900
#
#                                      25%          50%          75%
# age                            13.000000    23.000000    36.000000  \
# weight                         46.000000    61.000000    83.000000
# height                        156.484525   163.128234   163.223354
# gender                          0.000000     0.000000     1.000000
# BMI                            19.557137    23.056039    31.334294
# BMR                          1320.322500  1493.165000  1602.488000
# activity_level                  1.300000     1.500000     1.700000
# calories_to_maintain_weight  1815.879700  2104.599800  2405.301750
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %% [markdown]
# ### Filter the age
# - > 15

# %%
data=data[data['age']>15]
data
# Out:
#        age  weight      height  gender        BMI       BMR  activity_level
# 6000    16      52  159.620627       0  20.546999  1353.726             1.2  \
# 6002    16      49  161.203695       0  18.854317  1324.208             1.5
# 6010    16      52  159.233701       1  20.700007  1472.422             1.5
# 6014    16      49  160.025383       0  19.023991  1319.525             1.2
# 6016    16      48  160.189532       1  18.836919  1420.362             1.7
# ...    ...     ...         ...     ...        ...       ...             ...
# 23986   72      95  163.111254       0  35.874169  1510.154             1.3
# 23988   85      98  163.140906       0  36.812724  1473.418             1.7
# 23994   50      98  163.186416       0  36.711217  1635.925             1.7
# 23997   57      97  163.128970       0  36.386871  1593.981             1.3
# 23998   63      98  163.316817       1  36.597850  1791.512             1.2
#
#        calories_to_maintain_weight
# 6000                     1624.4712
# 6002                     1986.3120
# 6010                     2208.6330
# 6014                     1583.4300
# 6016                     2414.6154
# ...                            ...
# 23986                    1963.2002
# 23988                    2504.8106
# 23994                    2781.0725
# 23997                    2072.1753
# 23998                    2149.8144
#
# [7418 rows x 8 columns]

# %%
data.describe().transpose()
# Out:
#                               count         mean         std          min
# age                          7418.0    34.512537   16.683523    16.000000  \
# weight                       7418.0    74.607981   15.318408    48.000000
# height                       7418.0   163.006119    0.742508   158.761642
# gender                       7418.0     0.487193    0.499870     0.000000
# BMI                          7418.0    28.055802    5.686672    18.085729
# BMR                          7418.0  1573.504469  136.421130  1302.797000
# activity_level               7418.0     1.444217    0.223760     1.200000
# calories_to_maintain_weight  7418.0  2259.941566  313.938645  1563.356400
#
#                                      25%          50%          75%
# age                            22.000000    31.000000    42.000000  \
# weight                         61.000000    74.000000    90.000000
# height                        163.120555   163.185915   163.253802
# gender                          0.000000     0.000000     1.000000
# BMI                            22.716269    27.733425    33.642773
# BMR                          1472.150500  1557.963000  1634.942500
# activity_level                  1.300000     1.300000     1.700000
# calories_to_maintain_weight  2028.724050  2206.866300  2441.524500
#
#                                      max
# age                            90.000000
# weight                         99.000000
# height                        163.322265
# gender                          1.000000
# BMI                            37.142927
# BMR                          1914.374000
# activity_level                  1.900000
# calories_to_maintain_weight  2949.075500

# %%
X=data.drop(['calories_to_maintain_weight'],axis=1)
y=data['calories_to_maintain_weight']

# %%
normalizer = tf.keras.layers.experimental.preprocessing.Normalization(input_shape=(X.shape[1],),axis=-1)
normalizer.adapt(np.array(X))
print(normalizer.mean.numpy())
# Out:
# [3.4512539e+01 7.4607979e+01 1.6300612e+02 4.8719332e-01 2.8055801e+01
#  1.5735045e+03 1.4442167e+00]

# %% [markdown]
# ### Split the data

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8)
x_train.shape,x_test.shape
# Out:
# ((5934, 7), (1484, 7))

# %% [markdown]
# ### Create model

# %%
from tensorflow.keras import regularizers
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(128, input_shape=(X.shape[1],), activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(64, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(32, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(16, activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(10,activation='linear',kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(1,activation='linear'),
])
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 7)                 15
# _________________________________________________________________
# dense (Dense)                (None, 128)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                170
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 12,084
# Trainable params: 12,069
# Non-trainable params: 15
# _________________________________________________________________

# %%
history=model.fit(x_train, y_train, epochs=200, batch_size=8,
                  validation_split=0.2)
# Out:
# Epoch 1/200
# 594/594 [==============================] - 2s 4ms/step - loss: 414.2491 - val_loss: 30.4135
# Epoch 2/200
# 594/594 [==============================] - 2s 3ms/step - loss: 33.2187 - val_loss: 25.0018
# Epoch 3/200
# 594/594 [==============================] - 2s 3ms/step - loss: 32.7329 - val_loss: 30.3271
# Epoch 4/200
# 594/594 [==============================] - 2s 3ms/step - loss: 32.5384 - val_loss: 46.0998
# Epoch 5/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.9577 - val_loss: 33.3141
# Epoch 6/200
# 594/594 [==============================] - 2s 3ms/step - loss: 32.6817 - val_loss: 25.2292
# Epoch 7/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.4198 - val_loss: 35.3187
# Epoch 8/200
# 594/594 [==============================] - 2s 4ms/step - loss: 31.9641 - val_loss: 30.4614
# Epoch 9/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.0703 - val_loss: 28.7926
# Epoch 10/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.7540 - val_loss: 24.8946
# Epoch 11/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.7044 - val_loss: 31.1946
# Epoch 12/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.9509 - val_loss: 24.5817
# Epoch 13/200
# 594/594 [==============================] - 2s 3ms/step - loss: 30.7096 - val_loss: 27.8851
# Epoch 14/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.4608 - val_loss: 22.4633
# Epoch 15/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.1283 - val_loss: 27.5880
# Epoch 16/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.9557 - val_loss: 26.4780
# Epoch 17/200
# 594/594 [==============================] - 2s 4ms/step - loss: 30.1251 - val_loss: 34.8104
# Epoch 18/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.9456 - val_loss: 34.0546
# Epoch 19/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.0431 - val_loss: 32.2046
# Epoch 20/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.7208 - val_loss: 33.6332
# Epoch 21/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.9029 - val_loss: 42.1478
# Epoch 22/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.6062 - val_loss: 25.7067
# Epoch 23/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.5194 - val_loss: 23.8433
# Epoch 24/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.6205 - val_loss: 24.9137
# Epoch 25/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.9597 - val_loss: 25.9340
# Epoch 26/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.2674 - val_loss: 30.0497
# Epoch 27/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.1661 - val_loss: 36.1822
# Epoch 28/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.2541 - val_loss: 29.1607
# Epoch 29/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.0425 - val_loss: 25.9256
# Epoch 30/200
# 594/594 [==============================] - 2s 3ms/step - loss: 29.2267 - val_loss: 23.5907
# Epoch 31/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.8759 - val_loss: 23.0307
# Epoch 32/200
# 594/594 [==============================] - 2s 3ms/step - loss: 28.0902 - val_loss: 36.5209
# Epoch 33/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.6575 - val_loss: 25.5289
# Epoch 34/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.8887 - val_loss: 24.9617
# Epoch 35/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.2158 - val_loss: 25.5345
# Epoch 36/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.6681 - val_loss: 25.2109
# Epoch 37/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.8960 - val_loss: 26.6927
# Epoch 38/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.0759 - val_loss: 26.8910
# Epoch 39/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.2671 - val_loss: 23.2841
# Epoch 40/200
# 594/594 [==============================] - 2s 4ms/step - loss: 27.2415 - val_loss: 24.9199
# Epoch 41/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.6443 - val_loss: 23.2540
# Epoch 42/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.4235 - val_loss: 23.3848
# Epoch 43/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.3784 - val_loss: 39.6040
# Epoch 44/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.9155 - val_loss: 26.2168
# Epoch 45/200
# 594/594 [==============================] - 2s 4ms/step - loss: 26.9735 - val_loss: 34.5238
# Epoch 46/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.3086 - val_loss: 30.9700
# Epoch 47/200
# 594/594 [==============================] - 3s 4ms/step - loss: 26.4843 - val_loss: 24.6826
# Epoch 48/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.7331 - val_loss: 38.2036
# Epoch 49/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.1142 - val_loss: 26.6100
# Epoch 50/200
# 594/594 [==============================] - 2s 4ms/step - loss: 26.5924 - val_loss: 22.1066
# Epoch 51/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.5206 - val_loss: 27.5590
# Epoch 52/200
# 594/594 [==============================] - 3s 4ms/step - loss: 28.0437 - val_loss: 24.4924
# Epoch 53/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1583 - val_loss: 22.3626
# Epoch 54/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.6483 - val_loss: 22.9238
# Epoch 55/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.7017 - val_loss: 31.4034
# Epoch 56/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.3583 - val_loss: 21.4581
# Epoch 57/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.6521 - val_loss: 41.4841
# Epoch 58/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.6878 - val_loss: 20.8640
# Epoch 59/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.3861 - val_loss: 27.1267
# Epoch 60/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.4112 - val_loss: 22.8200
# Epoch 61/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.7982 - val_loss: 27.1520
# Epoch 62/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.5170 - val_loss: 23.7011
# Epoch 63/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.6080 - val_loss: 30.4059
# Epoch 64/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.4742 - val_loss: 19.5115
# Epoch 65/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.3486 - val_loss: 26.0251
# Epoch 66/200
# 594/594 [==============================] - 2s 3ms/step - loss: 27.1582 - val_loss: 22.5945
# Epoch 67/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1508 - val_loss: 33.4955
# Epoch 68/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.5145 - val_loss: 24.5106
# Epoch 69/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.3855 - val_loss: 31.8080
# Epoch 70/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.1712 - val_loss: 33.8389
# Epoch 71/200
# 594/594 [==============================] - 2s 3ms/step - loss: 26.0225 - val_loss: 26.5942
# Epoch 72/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.4185 - val_loss: 36.8089
# Epoch 73/200
# 594/594 [==============================] - 3s 5ms/step - loss: 24.8584 - val_loss: 28.0929
# Epoch 74/200
# 594/594 [==============================] - 3s 5ms/step - loss: 24.8073 - val_loss: 39.1234
# Epoch 75/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.7361 - val_loss: 22.2493
# Epoch 76/200
# 594/594 [==============================] - 2s 4ms/step - loss: 26.6331 - val_loss: 33.2283
# Epoch 77/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.8256 - val_loss: 25.3156
# Epoch 78/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.3815 - val_loss: 20.6637
# Epoch 79/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1953 - val_loss: 20.9085
# Epoch 80/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.5884 - val_loss: 19.6731
# Epoch 81/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.5646 - val_loss: 22.6409
# Epoch 82/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.7168 - val_loss: 22.2515
# Epoch 83/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.9127 - val_loss: 30.3153
# Epoch 84/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.5074 - val_loss: 21.7661
# Epoch 85/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1144 - val_loss: 21.7295
# Epoch 86/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0624 - val_loss: 27.4835
# Epoch 87/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1359 - val_loss: 47.6041
# Epoch 88/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.5776 - val_loss: 21.5054
# Epoch 89/200
# 594/594 [==============================] - 3s 4ms/step - loss: 24.0085 - val_loss: 28.0167
# Epoch 90/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.7419 - val_loss: 22.6518
# Epoch 91/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.0846 - val_loss: 29.1775
# Epoch 92/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.6954 - val_loss: 34.0645
# Epoch 93/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.4628 - val_loss: 26.2610
# Epoch 94/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.0842 - val_loss: 36.0319
# Epoch 95/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.0779 - val_loss: 25.2267
# Epoch 96/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3113 - val_loss: 22.3027
# Epoch 97/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.9336 - val_loss: 32.9829
# Epoch 98/200
# 594/594 [==============================] - 2s 4ms/step - loss: 23.8911 - val_loss: 24.8314
# Epoch 99/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.8098 - val_loss: 29.0511
# Epoch 100/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6627 - val_loss: 23.2056
# Epoch 101/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.2946 - val_loss: 29.9232
# Epoch 102/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.3965 - val_loss: 21.0502
# Epoch 103/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7187 - val_loss: 26.3776
# Epoch 104/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1926 - val_loss: 27.1525
# Epoch 105/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.4177 - val_loss: 18.6546
# Epoch 106/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.1594 - val_loss: 24.9566
# Epoch 107/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.5018 - val_loss: 29.1064
# Epoch 108/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.4715 - val_loss: 21.3151
# Epoch 109/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.1802 - val_loss: 28.0298
# Epoch 110/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.4830 - val_loss: 37.6876
# Epoch 111/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1220 - val_loss: 22.3771
# Epoch 112/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.4117 - val_loss: 22.6969
# Epoch 113/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.2624 - val_loss: 27.0076
# Epoch 114/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6257 - val_loss: 23.3125
# Epoch 115/200
# 594/594 [==============================] - 3s 5ms/step - loss: 25.0165 - val_loss: 29.4015
# Epoch 116/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.0400 - val_loss: 26.0615
# Epoch 117/200
# 594/594 [==============================] - 2s 4ms/step - loss: 23.5785 - val_loss: 26.3027
# Epoch 118/200
# 594/594 [==============================] - 2s 4ms/step - loss: 24.9167 - val_loss: 21.4750
# Epoch 119/200
# 594/594 [==============================] - 2s 4ms/step - loss: 22.8514 - val_loss: 19.5012
# Epoch 120/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.1227 - val_loss: 30.4805
# Epoch 121/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.0067 - val_loss: 21.3607
# Epoch 122/200
# 594/594 [==============================] - 2s 4ms/step - loss: 23.5811 - val_loss: 18.5303
# Epoch 123/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3353 - val_loss: 27.2783
# Epoch 124/200
# 594/594 [==============================] - 2s 4ms/step - loss: 25.2390 - val_loss: 20.2454
# Epoch 125/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.8071 - val_loss: 19.8229
# Epoch 126/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6923 - val_loss: 22.8774
# Epoch 127/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.9598 - val_loss: 35.2868
# Epoch 128/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.9892 - val_loss: 23.2368
# Epoch 129/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.6757 - val_loss: 42.7428
# Epoch 130/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7123 - val_loss: 20.5194
# Epoch 131/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7681 - val_loss: 24.2169
# Epoch 132/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1081 - val_loss: 21.1861
# Epoch 133/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.2479 - val_loss: 19.2043
# Epoch 134/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.8652 - val_loss: 19.8901
# Epoch 135/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.1280 - val_loss: 20.9371
# Epoch 136/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0189 - val_loss: 21.3803
# Epoch 137/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5949 - val_loss: 32.8515
# Epoch 138/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7568 - val_loss: 22.9752
# Epoch 139/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0124 - val_loss: 18.3558
# Epoch 140/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0089 - val_loss: 21.9551
# Epoch 141/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.8956 - val_loss: 25.9338
# Epoch 142/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.8526 - val_loss: 34.5167
# Epoch 143/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.0840 - val_loss: 30.5063
# Epoch 144/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5657 - val_loss: 19.0695
# Epoch 145/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0067 - val_loss: 24.7543
# Epoch 146/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5289 - val_loss: 20.9470
# Epoch 147/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.4870 - val_loss: 49.7790
# Epoch 148/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7468 - val_loss: 33.2875
# Epoch 149/200
# 594/594 [==============================] - 2s 3ms/step - loss: 25.0541 - val_loss: 22.7860
# Epoch 150/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.1233 - val_loss: 18.5034
# Epoch 151/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.0236 - val_loss: 19.7623
# Epoch 152/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6182 - val_loss: 21.9377
# Epoch 153/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.8637 - val_loss: 31.4139
# Epoch 154/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.6080 - val_loss: 18.8956
# Epoch 155/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3035 - val_loss: 18.5511
# Epoch 156/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.1575 - val_loss: 18.2439
# Epoch 157/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.4313 - val_loss: 19.1184
# Epoch 158/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.5277 - val_loss: 36.1738
# Epoch 159/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.7260 - val_loss: 25.0598
# Epoch 160/200
# 594/594 [==============================] - 2s 3ms/step - loss: 24.0336 - val_loss: 23.9151
# Epoch 161/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3073 - val_loss: 24.3337
# Epoch 162/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.5234 - val_loss: 18.6811
# Epoch 163/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.0351 - val_loss: 23.9076
# Epoch 164/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.1285 - val_loss: 19.9421
# Epoch 165/200
# 594/594 [==============================] - 2s 4ms/step - loss: 22.8992 - val_loss: 19.8579
# Epoch 166/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.6250 - val_loss: 22.5907
# Epoch 167/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3217 - val_loss: 29.8860
# Epoch 168/200
# 594/594 [==============================] - 2s 4ms/step - loss: 22.4732 - val_loss: 22.6037
# Epoch 169/200
# 594/594 [==============================] - 2s 4ms/step - loss: 23.4725 - val_loss: 21.9690
# Epoch 170/200
# 594/594 [==============================] - 2s 4ms/step - loss: 22.5920 - val_loss: 22.1766
# Epoch 171/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.3944 - val_loss: 21.7118
# Epoch 172/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.8906 - val_loss: 30.0568
# Epoch 173/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.7597 - val_loss: 20.9118
# Epoch 174/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.5627 - val_loss: 18.8843
# Epoch 175/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.9712 - val_loss: 19.4153
# Epoch 176/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.2281 - val_loss: 24.5121
# Epoch 177/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.7519 - val_loss: 20.1184
# Epoch 178/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3472 - val_loss: 19.6700
# Epoch 179/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.2930 - val_loss: 23.2456
# Epoch 180/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3488 - val_loss: 24.2245
# Epoch 181/200
# 594/594 [==============================] - 2s 3ms/step - loss: 23.4455 - val_loss: 26.8472
# Epoch 182/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.5531 - val_loss: 23.4151
# Epoch 183/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.1225 - val_loss: 23.4414
# Epoch 184/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.7034 - val_loss: 35.6395
# Epoch 185/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.0324 - val_loss: 21.4378
# Epoch 186/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.2513 - val_loss: 18.6553
# Epoch 187/200
# 594/594 [==============================] - 2s 4ms/step - loss: 21.8695 - val_loss: 21.3663
# Epoch 188/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3001 - val_loss: 26.0548
# Epoch 189/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3455 - val_loss: 21.0964
# Epoch 190/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.3250 - val_loss: 20.6306
# Epoch 191/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.1147 - val_loss: 20.1050
# Epoch 192/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.3910 - val_loss: 19.3137
# Epoch 193/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.6021 - val_loss: 18.9320
# Epoch 194/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.7849 - val_loss: 19.6904
# Epoch 195/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.4207 - val_loss: 20.0601
# Epoch 196/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.7188 - val_loss: 19.8534
# Epoch 197/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.9840 - val_loss: 25.1424
# Epoch 198/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.8356 - val_loss: 20.9649
# Epoch 199/200
# 594/594 [==============================] - 2s 3ms/step - loss: 22.8363 - val_loss: 22.4807
# Epoch 200/200
# 594/594 [==============================] - 2s 3ms/step - loss: 21.6739 - val_loss: 20.0639

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def plot_loss(history,start,end):
  x_index=[x for x in range (start,end)]
  plt.plot(x_index,history.history['loss'][start-1:end-1], label='loss')
  plt.plot(x_index,history.history['val_loss'][start-1:end-1], label='val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss MAE')
  plt.title(f'Loss betweeh epoch {start} and {end}')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
plot_loss(history,5,200)

# %%
model.evaluate(x_test,y_test)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 19.4352
# 19.4351749420166

# %%
predict=model.predict(x_test)
predict.squeeze()
# Out:
# array([2400.2087, 1941.5096, 2225.5806, ..., 1782.8182, 1972.63  ,
#        2064.8896], dtype=float32)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your true labels in a NumPy array called 'y_true'
# Assuming you have your predicted values in a NumPy array called 'y_pred'

# Calculate the difference between true labels and predicted values
diff = y_test - predict.squeeze()

# Plotting the difference
plt.plot(np.arange(len(diff)), diff)
plt.xlabel('Sample Index')
plt.ylabel('Difference')
plt.title('Regression: Difference between True Labels and Predicted Values')
plt.show()

# %%
diff.describe()
# Out:
# count    1484.000000
# mean        5.190200
# std        24.273412
# min       -76.285772
# 25%       -12.631463
# 50%         5.590101
# 75%        17.593017
# max       100.603848
# Name: calories_to_maintain_weight, dtype: float64

# %%
import numpy as np

test=np.array([21,48,155,0,20,1183,1.2],dtype=float) # single row data -> prediksi 1 data orang sesuai dengan atribut yg ada
test=np.expand_dims(test,axis=0)
test
# Out:
# array([[  21. ,   48. ,  155. ,    0. ,   20. , 1183. ,    1.2]])

# %%
model.predict(test)
# Out:
# array([[1413.4332]], dtype=float32)

# %%
# model.save('model_2_linear.h5')
